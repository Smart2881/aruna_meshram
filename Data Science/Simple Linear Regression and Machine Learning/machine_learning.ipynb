# %% [markdown]
# # Machine Learning

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)    | Output     | Justification     |
# | ---- | ----------- | ---------  | ---------  |
# | 1.1  |Maps, Images of road/traffic lights, Radar sensor         |Automatic gear transmission          |The self-driving car take several pieces of info, images and radar inputs. Processes these and provide instructions to transmission system to help control speed.          |
# | 1.2  |   Age, recently viewed items, user preferences |  Related recommended videos          |  The inputs age, preferences, etc are processed by Recommender system and users are provided with recommendations to watch          |
# | 1.3  |Previous signature samples, signature to be tested     |  Matched or unmatched or no-signature         |  Signature recognition algorithm uses previous example signatures, images to train and matches handwriting patterns and helps detect correct signature vs unmatched signatures         |
# | 1.4  |Signs and symptoms, Patient details, Patients stats, history | Name of illness, severity,           | The details inputted are used to match list of illness and its signs & symptoms to help diagnosis patient illness

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
# * 2.1 This is an example of classification model. It is a binary type of classification which is checking whether emails are promotional or social.
# * 2.2 This is a regression model, as it is predicting continuous numerical values for statistical data set.
# * 2.3 It is an example of classification model. Same as 2.1, is a binary type of classification which is checking images of animals and sorting them in categories.
# * 2.4 This is a classification model, it is trying to predict and classify, likelihood of patient having a disease or not depending on history and results.

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
# * 3.1 This type of data used for supervised learning, because labelled data will be able to detect outliers and detect accordingly.
# * 3.2 This type of data used for supervised learning. It comes under regression model as it is looking to predict continuous values.
# * 3.3 This type of data used for unsupervised learning. Unsupervised learning look for patterns, structures and relationships in data.
# * 3.4 This type of data utilised for unsupervised learning, to classify analysed posts. And, categorise them accordingly based on pattern

# %% [markdown]
# 4. For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
# * 4.1 We can use semi-supervised machine learning model as there's some date is unlabelled
# * 4.2 We can use semi-supervised, as it has data some data is unlabelled.
# * 4.3 We can use semi-supervised, as it has some data is labelled and some is not.
# * 4.4 We can't use semi-supervised, as the data is labelled. It will be better suited for supervised machine learning algorithms.
